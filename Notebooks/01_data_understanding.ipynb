# %% [markdown]
# <style>
# .jp-RenderedMarkdown, .rendered_html { font-family: Arial, Helvetica, sans-serif; font-size: 15px; line-height: 1.55; }
# .jp-RenderedMarkdown h1, .rendered_html h1 { font-size: 24px; font-weight: 700; }
# .jp-RenderedMarkdown h2, .rendered_html h2 { font-size: 20px; font-weight: 650; }
# .jp-RenderedMarkdown h3, .rendered_html h3 { font-size: 17px; font-weight: 600; }
# .jp-RenderedMarkdown p, .jp-RenderedMarkdown li, .rendered_html p, .rendered_html li { font-size: 15px; }
# .jp-RenderedMarkdown code, .rendered_html code { font-size: 13px; }
# </style>

# %% [markdown]
# # MeridianAI — Data Understanding
#
# # Notebook 01 – Data Understanding
#
# ## Objective
#
# The objective of this notebook is to understand the structure and characteristics of the Online Retail dataset before any preprocessing or machine learning is performed.
#
# The notebook focuses on:
#
# - Understanding the dataset structure
# - Exploring available features
# - Checking data types
# - Identifying missing values
# - Understanding statistical properties
# - Performing an initial inspection of customer transaction data
#
# This notebook serves as the foundation for all subsequent notebooks in the MeridianAI project.

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

sns.set_style("whitegrid")

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("../data/raw/online_retail_II.csv")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# # Dataset Shape

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 1067371
# Columns : 8

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  str
#  1   StockCode    1067371 non-null  str
#  2   Description  1062989 non-null  str
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  str
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 136.6 MB

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='str')

# %% [markdown]
# # Statistical Summary

# %%
df.describe(include="all")
# Out:
#         Invoice StockCode                         Description      Quantity  \
# count   1067371   1067371                             1062989  1.067371e+06
# unique    53628      5305                                5698           NaN
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER           NaN
# freq       1350      5829                                5918           NaN
# mean        NaN       NaN                                 NaN  9.938898e+00
# std         NaN       NaN                                 NaN  1.727058e+02
# min         NaN       NaN                                 NaN -8.099500e+04
# 25%         NaN       NaN                                 NaN  1.000000e+00
# 50%         NaN       NaN                                 NaN  3.000000e+00
# 75%         NaN       NaN                                 NaN  1.000000e+01
# max         NaN       NaN                                 NaN  8.099500e+04
#
# ...

# %% [markdown]
# # Missing Values

# %%
missing = df.isnull().sum().sort_values(ascending=False)

missing
# Out:
# Customer ID    243007
# Description      4382
# StockCode           0
# Invoice             0
# Quantity            0
# InvoiceDate         0
# Price               0
# Country             0
# dtype: int64

# %% [markdown]
# # Duplicate Records

# %%
print(df.duplicated().sum())
# Out:
# 34335

# %% [markdown]
# # Sample Customer Transactions

# %%
df.sample(10)
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 371450    525235     22036            DINOSAUR BIRTHDAY CARD         1
# 741191    555731     22692       DOORMAT WELCOME TO OUR HOME         2
# 948015    573094     21535      RED RETROSPOT SMALL MILK JUG         2
# 696026   C551335     22914      BLUE COAT RACK PARIS FASHION        -1
# 303220    518948     22169  FAMILY ALBUM WHITE PICTURE FRAME         2
# 188747    507292     22088       PAPER BUNTING COLOURED LACE         2
# 1055824   580852     23583          LUNCH BAG PAISLEY PARK          10
# 239621    512553     21504              SKULLS GREETING CARD        12
# 364766    524727     22759      SET OF 3 NOTEBOOKS IN PARCEL        12
# 596135    542093     48187               DOORMAT NEW ENGLAND        10
#
#                  InvoiceDate  Price  Customer ID         Country
# 371450   2010-10-04 14:30:00   0.85          NaN  United Kingdom
# ...

# %% [markdown]
# # Initial Business Observations
#
# From the initial inspection of the dataset, several important observations can be made:
#
# - The dataset contains transactional information for an online retail business.
# - Customer purchases are recorded at the invoice level.
# - Some features contain missing values.
# - Duplicate records are present.
# - InvoiceDate requires datetime conversion.
# - Quantity and UnitPrice require validation before analysis.
# - CustomerID will be used to aggregate transactions into customer-level features in later notebooks.
#
# The next notebook focuses on cleaning the dataset and preparing it for customer analytics.
